# %%
# import necessary libraries
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
# import data from yfinance
symbols = ['RR.L', 'AUTO.L']

# %%
# select dates (in this case , 2 years starting from today)
end_date = datetime.now()
start_date = end_date - timedelta(days=2*365)

# %%
# Download chosen data
data = yf.download(symbols, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data.head()
# Out:
# Price                       Adj Close                  Close             \
# Ticker                         AUTO.L       RR.L      AUTO.L       RR.L
# Date
# 2022-10-17 00:00:00+00:00  516.692566  71.570000  530.799988  71.570000
# 2022-10-18 00:00:00+00:00  518.639404  74.279999  532.799988  74.279999
# 2022-10-19 00:00:00+00:00  504.038055  74.000000  517.799988  74.000000
# 2022-10-20 00:00:00+00:00  504.427429  73.150002  518.200012  73.150002
# 2022-10-21 00:00:00+00:00  473.277924  73.580002  486.200012  73.580002
#
# Price                            High                    Low             \
# Ticker                         AUTO.L       RR.L      AUTO.L       RR.L
# Date
# 2022-10-17 00:00:00+00:00  539.000000  71.699997  514.799988  70.089996
# 2022-10-18 00:00:00+00:00  538.400024  74.889999  526.400024  71.610001
# 2022-10-19 00:00:00+00:00  534.200012  75.660004  507.600006  72.599998
# 2022-10-20 00:00:00+00:00  519.000000  74.075996  503.600006  72.110001
# 2022-10-21 00:00:00+00:00  513.400024  73.720001  479.799988  70.889999
#
# Price                            Open              Volume
# Ticker                         AUTO.L       RR.L   AUTO.L      RR.L
# Date
# 2022-10-17 00:00:00+00:00  523.000000  71.050003  3401358  21642439
# 2022-10-18 00:00:00+00:00  533.799988  73.120003  1632833  83013326
# 2022-10-19 00:00:00+00:00  534.200012  74.889999  2462158  23620912
# 2022-10-20 00:00:00+00:00  514.400024  74.000000  3171236  18380472
# 2022-10-21 00:00:00+00:00  510.399994  72.110001  5085596  22192578
